# %% [markdown]
# #NumPy Challenge

# %% [markdown]
# Create a NumPy ndarray object by using this list of numbers [7,8,4,5,1,2].

# %%
import numpy as np
arr = np.array([7,8,4,5,1,2])
print(arr)

# %% [markdown]
# Using slicing print the elements from index 3 to the end of the array.

# %%
import numpy as np
arr = np.array([7,8,4,5,1,2])

print(arr[3:])
# Out:
# [5 1 2]

# %% [markdown]
# Using slicing print all the elements except the last one.

# %%
import numpy as np
arr = np.array([7,8,4,5,1,2])

print(arr[:5])
# Out:
# [7 8 4 5 1]

# %% [markdown]
# Using slicing print the elements from index 1 to index 4 of the array.

# %%
import numpy as np
arr = np.array([7,8,4,5,1,2])

print(arr[:4])
# Out:
# [7 8 4 5]

# %% [markdown]
# Reshape the array into a 3 rows and 2 cols (3,2).

# %%
import numpy as np
arr = np.array([7,8,4,5,1,2])
print(arr.reshape(3, 2))
# Out:
# [[7 8]
#  [4 5]
#  [1 2]]

# %% [markdown]
# Print all the array elements one by one (iterating).

# %%
import numpy as np
arr = np.array([7,8,4,5,1,2])
for idx, x in np.ndenumerate(arr):
  print(idx, x)
# Out:
# (0,) 7
# (1,) 8
# (2,) 4
# (3,) 5
# (4,) 1
# (5,) 2

# %% [markdown]
# Create a new NumPy ndarray object by using this list of numbers [0,6,9].

# %%
import numpy as np
arr = np.array([0,6,9])
print(arr)
# Out:
# [0 6 9]

# %% [markdown]
# Join the two arrays.

# %%
import numpy as np
arr1 = np.array([0,6,9])
arr2 = np.array([7,8,4,5,1,2])
arr = np.concatenate((arr1, arr2))             
print(arr)
# Out:
# [0 6 9 7 8 4 5 1 2]

# %% [markdown]
# Using filtering print only the odd numbers of the joined array.

# %%
import numpy as np
arr1 = np.array([0,6,9])
arr2 = np.array([7,8,4,5,1,2])
arr = np.concatenate((arr1, arr2))  
odd = np.where(arr%2 != 0)   
print(odd)
# Out:
# (array([2, 3, 6, 7]),)

# %% [markdown]
# Sort the joined array elements.

# %%
import numpy as np
arr1 = np.array([0,6,9])
arr2 = np.array([7,8,4,5,1,2])
arr = np.concatenate((arr1, arr2)) 
sort = np.sort(arr)
print(sort)
# Out:
# [0 1 2 4 5 6 7 8 9]

# %% [markdown]
# Store in an array the names of the months.

# %%
import numpy as np
arr = np.array(['enero','febrero','marzo','abril','mayo','junio','julio','agosto','septiembre','octubre','noviembre','diciembre'])
print(arr)
# Out:
# ['enero' 'febrero' 'marzo' 'abril' 'mayo' 'junio' 'julio' 'agosto'
#  'septiembre' 'octubre' 'noviembre' 'diciembre']

# %% [markdown]
# Split the months array in 4 periods of 3 elements each one.

# %%
import numpy as np
arr = np.array(['enero','febrero','marzo','abril','mayo','junio','julio','agosto','septiembre','octubre','noviembre','diciembre'])
split= arr.reshape(4, 3)
print(split)
# Out:
# [['enero' 'febrero' 'marzo']
#  ['abril' 'mayo' 'junio']
#  ['julio' 'agosto' 'septiembre']
#  ['octubre' 'noviembre' 'diciembre']]

# %% [markdown]
# Create an array with genre information ['F','M','F','F','M','F'].

# %%
import numpy as np
arr = np.array(['F','M','F','F','M','F'])
print(arr)
# Out:
# ['F' 'M' 'F' 'F' 'M' 'F']

# %% [markdown]
# Find the indexes where the value is F.

# %%
import numpy as np
arr = np.array(['F','M','F','F','M','F'])
find =np.searchsorted(arr, 'F')
print(find)
# Out:
# 0

# %% [markdown]
# Store in an array the age information [18,20,19,23,19,20].

# %%
import numpy as np
arr = np.array([18,20,19,23,19,20])
print(arr)
# Out:
# [18 20 19 23 19 20]

# %% [markdown]
# Create a filter array with values < 20.

# %%
import numpy as np
arr = np.array([18,20,19,23,19,20])

filter_arr = arr <20
newarr = arr[filter_arr]

print(filter_arr)
print(newarr)
# Out:
# [ True False  True False  True False]
# [18 19 19]

# %% [markdown]
# Change the 3 index element with a value of 22

# %%
import numpy as np #0 el índice del primer elemento
arr = np.array([18,20,19,23,19,20])
change = arr.view()
change[3] = 22
print(change)
# Out:
# [18 20 22 23 19 20]

# %% [markdown]
# Print the 4 index element.

# %%
import numpy as np 
arr = np.array([18,20,19,23,19,20])
change = arr.view()
change[2] = 22
print(change[4])
# Out:
# 19
